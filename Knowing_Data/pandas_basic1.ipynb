# %% [markdown]
# Getting and Knowing data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 1: Import DB

# %%
df = pd.read_csv("chipotle (1).tsv",sep="\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# loc vs iloc

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.loc[(df.quantity == 2) & (df.item_name == "Nantucket Nectar"),['order_id','quantity']]
# Out:
#       order_id  quantity
# 601        247         2
# 2379       947         2

# %%
df.iloc[[9]]
# Out:
#    order_id  quantity      item_name  \
# 9         5         1  Steak Burrito
#
#                                   choice_description item_price
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
df.iloc[3:11]
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 3                                                 NaN     $2.39
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45

# %%
df.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# Apply()

# %%
df.item_price=df.item_price.apply(lambda x:float( x.replace('$','')))

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['total_price'] = df['quantity'] * df['item_price']

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
revenue=df.total_price.sum()
print(revenue)
# Out:
# 39237.02

# %% [markdown]
# Group By:
# Which was the most-ordered item?

# %%
c = df.groupby("item_name")["quantity"].sum()
c.sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
df.item_name.value_counts().count()
# Out:
# np.int64(50)

# %%
df.item_name.nunique()
# Out:
# 50

# %%
df.total_price.dtype
# Out:
# dtype('float64')

# %%
df.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description  \
# count   4622.000000  4622.000000          4622               3376
# unique          NaN          NaN            50               1043
# top             NaN          NaN  Chicken Bowl        [Diet Coke]
# freq            NaN          NaN           726                134
# mean     927.254868     1.075725           NaN                NaN
# std      528.890796     0.410186           NaN                NaN
# min        1.000000     1.000000           NaN                NaN
# 25%      477.250000     1.000000           NaN                NaN
# 50%      926.000000     1.000000           NaN                NaN
# 75%     1393.000000     1.000000           NaN                NaN
# max     1834.000000    15.000000           NaN                NaN
#
#          item_price  total_price
# count   4622.000000  4622.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean       7.464336     8.489186
# std        4.245557    12.632060
# min        1.090000     1.090000
# 25%        3.390000     3.990000
# 50%        8.750000     8.750000
# 75%        9.250000    10.980000
# max       44.250000   663.750000

# %%
dates = pd.date_range("20130101", periods=6)

# %%
df2=pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df2.to_numpy()
# Out:
# array([[-0.76766201, -0.5052186 , -0.76540299, -0.6380221 ],
#        [-0.75377396,  1.42886196,  0.70141503,  0.71493134],
#        [ 0.32614258, -0.94740897,  0.5008372 , -1.59148779],
#        [-0.68430546,  0.80833024, -0.72572536, -1.41022705],
#        [ 0.04945597,  0.19425019, -0.19712649,  2.05165001],
#        [-2.3139167 , -0.57843719,  0.87935908, -0.2241033 ]])

# %%
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -0.767662 -0.505219 -0.765403 -0.638022
# 2013-01-02 -0.753774  1.428862  0.701415  0.714931
# 2013-01-03  0.326143 -0.947409  0.500837 -1.591488
# 2013-01-04 -0.684305  0.808330 -0.725725 -1.410227
# 2013-01-05  0.049456  0.194250 -0.197126  2.051650
# 2013-01-06 -2.313917 -0.578437  0.879359 -0.224103

# %%
df2.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.767662   -0.753774    0.326143   -0.684305    0.049456   -2.313917
# B   -0.505219    1.428862   -0.947409    0.808330    0.194250   -0.578437
# C   -0.765403    0.701415    0.500837   -0.725725   -0.197126    0.879359
# D   -0.638022    0.714931   -1.591488   -1.410227    2.051650   -0.224103
